# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
torch.manual_seed(123)
import torchvision
from torchvision.ops import box_convert, box_iou
import math
from torch.utils.data import TensorDataset
import copy

# %% [markdown]
# ### Load data and preprocessing

# %%
def normalize(train, val, test):
    train_tensors = train.tensors[0]  # Get the underlying tensor
    val_tensors = val.tensors[0]  
    test_tensors = test.tensors[0]  

    mean = train_tensors.mean()    # Mean per feature
    std  = train_tensors.std()     # Std per feature
    
    train_norm = (train_tensors - mean) / std 
    val_norm = (val_tensors - mean) / std 
    test_norm = (test_tensors - mean) / std 
    return TensorDataset(train_norm, train.tensors[1]), TensorDataset(val_norm, val.tensors[1]), TensorDataset(test_norm, test.tensors[1])

# %%
def load_data():
    train = torch.load('data/localization_train.pt', weights_only=False)
    val = torch.load('data/localization_val.pt', weights_only=False)
    test = torch.load('data/localization_test.pt', weights_only=False)
    norm_train, norm_val, norm_test = normalize(train, val, test)
    return train, val, test, norm_train, norm_val, norm_test

train, val, test, norm_train, norm_val, norm_test = load_data()
print(f'Train size: {len(train)}')
print(f'Val size: {len(val)}')
print(f'Test size: {len(test)}')  


labels = train.tensors[1]
class_ids = labels[:, 0]
digits = labels[:, -1].long() 

total = len(labels)
no_object = (class_ids == 0).sum().item()
has_object = (class_ids != 0).sum().item()

digit_counts = torch.bincount(digits, minlength=10)
for i in range(10):
    percentage = (digit_counts[i].item() / total) * 100 if total > 0 else 0
    print(f"Digit: {i}: {percentage:.2f}%")

print(f"Color-range: {int(train.tensors[0].min().item())} to {int(train.tensors[0].max().item())}")
print(f"Total samples: {total}")
print(f"No object: {no_object}")
print(f"Has object: {has_object}")
print(f"Image shape: {train.tensors[0].shape[1:]}")
print("Label:", train.tensors[1][0])
# Out:
# Train size: 59400
# Val size: 6600
# Test size: 11000
# Digit: 0: 9.00%
# Digit: 1: 19.32%
# Digit: 2: 9.03%
# Digit: 3: 9.30%
# Digit: 4: 8.83%
# Digit: 5: 8.23%
# Digit: 6: 8.94%
# Digit: 7: 9.50%
# Digit: 8: 8.84%
# Digit: 9: 9.02%
# Color-range: 0 to 1
# Total samples: 59400
# No object: 5400
# Has object: 54000
# Image shape: torch.Size([1, 48, 60])
# Label: tensor([1.0000, 0.6000, 0.2292, 0.3667, 0.4167, 4.0000])

# %% [markdown]
# ## Data exploration

# %%
def get_drawn_image(ds, i=0):
    img = ds.tensors[0][i]         
    y   = ds.tensors[1][i].float()  
    H, W = img.shape[-2], img.shape[-1]


    box = y[1:5].unsqueeze(0)              
    box_xyxy = box_convert(box, "cxcywh", "xyxy")  

    # Scale to pixels
    box_xyxy = box_xyxy * torch.tensor([W, H, W, H], dtype=torch.float32)

    # Makes image clearer for preview 
    img_u8 = (img.clamp(0,1) * 255).to(torch.uint8).repeat(3, 1, 1)

    if int(y[0].item()) == 0:
        return img_u8.permute(1,2,0).numpy(), int(y[0].item()), '?'

    drawn = torchvision.utils.draw_bounding_boxes(img_u8, box_xyxy, colors="red", width=1)
    return drawn.permute(1,2,0).numpy(), bool(y[0].item()), int(y[-1].item())


def show_samples(ds, n=7):
    cols = 4
    rows = math.ceil(n / cols)

    fig, axes = plt.subplots(rows, cols, figsize=(4*cols, 4*rows))
    axes = axes.flatten()  

    for i in range(n):
        img, cls, number = get_drawn_image(ds, i)
        axes[i].imshow(img)
        axes[i].set_title(f"Object: {cls}, Number: {number}")
        axes[i].axis("off")

    # Hide empty subplot if n does not fill the grid
    for j in range(n, len(axes)):
        axes[j].axis("off")

    plt.tight_layout()
    plt.savefig(f"figures/localization_exploration.png", bbox_inches="tight")
    plt.show()

show_samples(train, 16)

# %% [markdown]
# ## Model definition

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Training on device {device}.")

output_size = int(train.tensors[1][:, 5].max().item()) + 1
print(f"{output_size-5} classes")

class Net(nn.Module):
    def __init__(self, input_channels=1, input_size=(48, 60), conv_configs=None,
                 fc_hidden_sizes=None, output_size=15, pool_size=2, dropout=0.0):
        super().__init__()
        if conv_configs is None:    conv_configs = [(6, 5), (16, 5)]
        if fc_hidden_sizes is None: fc_hidden_sizes = [120, 84]

        self.pool = nn.MaxPool2d(pool_size, pool_size)
        self.dropout = nn.Dropout(dropout)

        self.convs = nn.ModuleList()
        in_ch = input_channels
        for out_ch, k in conv_configs:
            self.convs.append(nn.Conv2d(in_ch, out_ch, k))
            in_ch = out_ch

        with torch.no_grad():
            dummy = torch.zeros(1, input_channels, *input_size)
            for conv in self.convs:
                dummy = self.pool(F.relu(conv(dummy)))
            flat_size = dummy.view(1, -1).shape[1]

        self.fcs = nn.ModuleList()
        in_feat = flat_size
        for hidden in fc_hidden_sizes:
            self.fcs.append(nn.Linear(in_feat, hidden))
            in_feat = hidden
        self.out = nn.Linear(in_feat, output_size)

    def forward(self, x):
        for conv in self.convs:
            x = self.pool(F.relu(conv(x)))
        x = x.view(x.size(0), -1)
        for fc in self.fcs:
            x = self.dropout(F.relu(fc(x)))
        return self.out(x)
# Out:
# Training on device cuda.
# 10 classes

# %% [markdown]
# ## Localization

# %%
def localization_loss(y_pred, y_true):
    obj_mask = y_true[:, 0] > 0.5 

    # LA: detection (all samples)
    det_loss = F.binary_cross_entropy_with_logits(y_pred[:, 0], y_true[:, 0])

    if obj_mask.any():
        # LB: bbox only for positives
        box_loss = F.mse_loss(y_pred[obj_mask, 1:5], y_true[obj_mask, 1:5])

        # LC: class only for positives
        target = y_true[obj_mask, 5].long()         
        logits = y_pred[obj_mask, 5:]               

        C = logits.shape[1]
        if target.min() < 0 or target.max() >= C:
            raise ValueError(f"class target out of range: min={target.min().item()} max={target.max().item()} C={C}")

        cls_loss = F.cross_entropy(logits, target)
    else:
        box_loss = y_pred.new_tensor(0.0)
        cls_loss = y_pred.new_tensor(0.0)

    return det_loss + box_loss + cls_loss

# %% [markdown]
# ### Predictions

# %%
def predict(net, dataloader):
    net.eval()

    all_preds = []
    correct = 0
    total = 0
    total_iou = 0.0
    iou_count = 0

    with torch.no_grad():
        for inputs, targets in dataloader:
            inputs = inputs.to(device)
            targets = targets.to(device)

            outputs = net(inputs)
            all_preds.append(outputs.cpu())

            pc_true = targets[:, 0] > 0.5
            detected = torch.sigmoid(outputs[:, 0]) > 0.5

            class_pred = torch.argmax(outputs[:, 5:], dim=1)
            class_true = targets[:, 5].long()
            pc_pred = torch.sigmoid(outputs[:, 0])


            total += pc_true.sum().item()
            if pc_true.any():
                idx = torch.where(pc_true)[0]
                correct += (detected[idx] & (class_pred[idx] == class_true[idx])).sum().item()

                box_pred = outputs[:, 1:5].clone()
                box_true = targets[:, 1:5].clone()

                box_pred[:, 2:] = box_pred[:, 2:].abs().clamp(min=1e-6)
                box_true[:, 2:] = box_true[:, 2:].abs().clamp(min=1e-6)

                pred_xyxy = box_convert(box_pred[idx], "cxcywh", "xyxy").clamp(0.0, 1.0)
                true_xyxy = box_convert(box_true[idx], "cxcywh", "xyxy").clamp(0.0, 1.0)

                ious = box_iou(pred_xyxy, true_xyxy).diag()
                total_iou += ious.sum().item()
                iou_count += ious.numel()

    accuracy = correct / total if total > 0 else 0.0
    mean_iou = total_iou / iou_count if iou_count > 0 else 0.0
    performance = 0.5 * (accuracy + mean_iou)


    return torch.cat(all_preds, dim=0), accuracy, mean_iou, performance

# %% [markdown]
# ### Training & Selection

# %%
def train_model(net, num_epochs=20, patience=5, lr=0.01, weight_decay=0.0):
    net = net.to(device)
    optimizer = optim.SGD(net.parameters(), lr=lr, momentum=0.9, weight_decay=weight_decay)
    trainloader = torch.utils.data.DataLoader(norm_train, batch_size=64, shuffle=True, num_workers=0)
    val_loader  = torch.utils.data.DataLoader(norm_val,   batch_size=64, shuffle=False, num_workers=0)

    best_perf = -float("inf")
    best_weights = copy.deepcopy(net.state_dict())
    epochs_no_improve = 0
    history = []

    for epoch in range(num_epochs):
        net.train()
        running_loss = 0.0
        for inputs, labels in trainloader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            loss = localization_loss(net(inputs), labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        train_loss = running_loss / len(trainloader)
        _, val_acc, val_iou, val_perf = predict(net, val_loader)
        print(f"Epoch {epoch+1:02d}/{num_epochs} | train_loss={train_loss:.4f} | "
              f"val_acc={val_acc:.4f} | val_iou={val_iou:.4f} | val_perf={val_perf:.4f}")
        history.append({"epoch": epoch+1, "train_loss": train_loss,
                        "val_acc": val_acc, "val_iou": val_iou, "val_perf": val_perf})

        if val_perf > best_perf:
            best_perf, best_weights, epochs_no_improve = val_perf, copy.deepcopy(net.state_dict()), 0
        else:
            epochs_no_improve += 1
        if epochs_no_improve >= patience:
            print(f"Early stopping at epoch {epoch+1}")
            break

    net.load_state_dict(best_weights)
    return net, history, best_perf


param_grid = [
    {"lr": 0.01,  "weight_decay": 0.0},
    {"lr": 0.01,  "weight_decay": 1e-4},
    {"lr": 0.001, "weight_decay": 0.0},
    {"lr": 0.001, "weight_decay": 1e-4},
]

model_configs = {
    "light": dict(conv_configs=[(4, 3), (8, 3)],            fc_hidden_sizes=[64]),
    "deep":  dict(conv_configs=[(32, 3), (64, 3), (128, 3)], fc_hidden_sizes=[512, 256],       dropout=0.5),
    "wide":  dict(conv_configs=[(32, 5), (64, 5)],           fc_hidden_sizes=[1024, 512, 256], dropout=0.3),
}

all_results = {} 

for model_name, cfg in model_configs.items():
    for params in param_grid:
        run_key = (model_name, params["lr"], params["weight_decay"])
        print(f"\n=== {model_name} | lr={params['lr']} | wd={params['weight_decay']} ===")
        net = Net(**cfg)
        trained_net, history, best_perf = train_model(net, **params)
        all_results[run_key] = (trained_net, history, best_perf)
        print(f"Finished — best_perf={best_perf:.4f}")

best_key, (best_model, best_history, best_perf) = max(all_results.items(), key=lambda x: x[1][2])
best_name, best_lr, best_wd = best_key
print(f"\nBest run: model={best_name} | lr={best_lr} | wd={best_wd} | perf={best_perf:.4f}")
# Out:
# === light | lr=0.01 | wd=0.0 ===
# Epoch 01/20 | train_loss=2.3255 | val_acc=0.2255 | val_iou=0.4304 | val_perf=0.3280
# Epoch 02/20 | train_loss=1.9124 | val_acc=0.4037 | val_iou=0.4025 | val_perf=0.4031
# Epoch 03/20 | train_loss=1.3780 | val_acc=0.5908 | val_iou=0.4366 | val_perf=0.5137
# Epoch 04/20 | train_loss=1.0558 | val_acc=0.6562 | val_iou=0.4522 | val_perf=0.5542
# Epoch 05/20 | train_loss=0.8957 | val_acc=0.6933 | val_iou=0.4368 | val_perf=0.5651
# Epoch 06/20 | train_loss=0.7847 | val_acc=0.7025 | val_iou=0.4232 | val_perf=0.5628
# Epoch 07/20 | train_loss=0.7081 | val_acc=0.6963 | val_iou=0.4089 | val_perf=0.5526
# Epoch 08/20 | train_loss=0.6546 | val_acc=0.6967 | val_iou=0.3976 | val_perf=0.5471
# Epoch 09/20 | train_loss=0.6166 | val_acc=0.7317 | val_iou=0.3963 | val_perf=0.5640
# Epoch 10/20 | train_loss=0.5808 | val_acc=0.7122 | val_iou=0.3708 | val_perf=0.5415
# Early stopping at epoch 10
# Finished — best_perf=0.5651
#
# === light | lr=0.01 | wd=0.0001 ===
# Epoch 01/20 | train_loss=2.2437 | val_acc=0.2613 | val_iou=0.4180 | val_perf=0.3396
# Epoch 02/20 | train_loss=1.7151 | val_acc=0.4687 | val_iou=0.4395 | val_perf=0.4541
# Epoch 03/20 | train_loss=1.2848 | val_acc=0.6125 | val_iou=0.4249 | val_perf=0.5187
# Epoch 04/20 | train_loss=1.0668 | val_acc=0.6085 | val_iou=0.4456 | val_perf=0.5271
# Epoch 05/20 | train_loss=0.9236 | val_acc=0.6465 | val_iou=0.4446 | val_perf=0.5456
# Epoch 06/20 | train_loss=0.8307 | val_acc=0.6932 | val_iou=0.4597 | val_perf=0.5764
# Epoch 07/20 | train_loss=0.7659 | val_acc=0.7028 | val_iou=0.4606 | val_perf=0.5817
# Epoch 08/20 | train_loss=0.7064 | val_acc=0.6928 | val_iou=0.4287 | val_perf=0.5608
# Epoch 09/20 | train_loss=0.6669 | val_acc=0.6965 | val_iou=0.4519 | val_perf=0.5742
# Epoch 10/20 | train_loss=0.6274 | val_acc=0.7015 | val_iou=0.4609 | val_perf=0.5812
# Epoch 11/20 | train_loss=0.5999 | val_acc=0.6945 | val_iou=0.4464 | val_perf=0.5705
# Epoch 12/20 | train_loss=0.5740 | val_acc=0.7085 | val_iou=0.4161 | val_perf=0.5623
# Early stopping at epoch 12
# Finished — best_perf=0.5817
#
# === light | lr=0.001 | wd=0.0 ===
# Epoch 01/20 | train_loss=2.5953 | val_acc=0.1300 | val_iou=0.2911 | val_perf=0.2105
# Epoch 02/20 | train_loss=2.4809 | val_acc=0.1633 | val_iou=0.3873 | val_perf=0.2753
# Epoch 03/20 | train_loss=2.2712 | val_acc=0.1983 | val_iou=0.4257 | val_perf=0.3120
# Epoch 04/20 | train_loss=2.1611 | val_acc=0.2185 | val_iou=0.4465 | val_perf=0.3325
# Epoch 05/20 | train_loss=2.1027 | val_acc=0.2245 | val_iou=0.4497 | val_perf=0.3371
# Epoch 06/20 | train_loss=2.0576 | val_acc=0.2493 | val_iou=0.4321 | val_perf=0.3407
# Epoch 07/20 | train_loss=2.0139 | val_acc=0.2578 | val_iou=0.4131 | val_perf=0.3355
# Epoch 08/20 | train_loss=1.9458 | val_acc=0.3023 | val_iou=0.4009 | val_perf=0.3516
# Epoch 09/20 | train_loss=1.8499 | val_acc=0.3663 | val_iou=0.4063 | val_perf=0.3863
# Epoch 10/20 | train_loss=1.7372 | val_acc=0.4127 | val_iou=0.3583 | val_perf=0.3855
# Epoch 11/20 | train_loss=1.6233 | val_acc=0.4558 | val_iou=0.3817 | val_perf=0.4188
# Epoch 12/20 | train_loss=1.5128 | val_acc=0.4877 | val_iou=0.3820 | val_perf=0.4348
# Epoch 13/20 | train_loss=1.4179 | val_acc=0.5217 | val_iou=0.4111 | val_perf=0.4664
# Epoch 14/20 | train_loss=1.3332 | val_acc=0.5562 | val_iou=0.3979 | val_perf=0.4771
# Epoch 15/20 | train_loss=1.2620 | val_acc=0.5687 | val_iou=0.4455 | val_perf=0.5071
# Epoch 16/20 | train_loss=1.1957 | val_acc=0.5903 | val_iou=0.4556 | val_perf=0.5230
# Epoch 17/20 | train_loss=1.1370 | val_acc=0.6027 | val_iou=0.4633 | val_perf=0.5330
# Epoch 18/20 | train_loss=1.0878 | val_acc=0.6103 | val_iou=0.4530 | val_perf=0.5317
# Epoch 19/20 | train_loss=1.0426 | val_acc=0.6250 | val_iou=0.4611 | val_perf=0.5430
# Epoch 20/20 | train_loss=1.0033 | val_acc=0.6302 | val_iou=0.4655 | val_perf=0.5478
# Finished — best_perf=0.5478
#
# === light | lr=0.001 | wd=0.0001 ===
# Epoch 01/20 | train_loss=2.6065 | val_acc=0.1128 | val_iou=0.2846 | val_perf=0.1987
# Epoch 02/20 | train_loss=2.5186 | val_acc=0.1497 | val_iou=0.3548 | val_perf=0.2523
# Epoch 03/20 | train_loss=2.3702 | val_acc=0.1608 | val_iou=0.4043 | val_perf=0.2826
# Epoch 04/20 | train_loss=2.2667 | val_acc=0.1817 | val_iou=0.4447 | val_perf=0.3132
# Epoch 05/20 | train_loss=2.1725 | val_acc=0.2053 | val_iou=0.4285 | val_perf=0.3169
# Epoch 06/20 | train_loss=2.1165 | val_acc=0.2135 | val_iou=0.4368 | val_perf=0.3252
# Epoch 07/20 | train_loss=2.0747 | val_acc=0.2187 | val_iou=0.4240 | val_perf=0.3214
# Epoch 08/20 | train_loss=2.0445 | val_acc=0.2360 | val_iou=0.4309 | val_perf=0.3334
# Epoch 09/20 | train_loss=2.0194 | val_acc=0.2473 | val_iou=0.4343 | val_perf=0.3408
# Epoch 10/20 | train_loss=1.9911 | val_acc=0.2687 | val_iou=0.4353 | val_perf=0.3520
# Epoch 11/20 | train_loss=1.9562 | val_acc=0.2908 | val_iou=0.4318 | val_perf=0.3613
# Epoch 12/20 | train_loss=1.9095 | val_acc=0.3187 | val_iou=0.4156 | val_perf=0.3671
# Epoch 13/20 | train_loss=1.8291 | val_acc=0.3578 | val_iou=0.4077 | val_perf=0.3828
# Epoch 14/20 | train_loss=1.7344 | val_acc=0.4013 | val_iou=0.4271 | val_perf=0.4142
# Epoch 15/20 | train_loss=1.6375 | val_acc=0.4422 | val_iou=0.4172 | val_perf=0.4297
# Epoch 16/20 | train_loss=1.5484 | val_acc=0.4698 | val_iou=0.4259 | val_perf=0.4479
# Epoch 17/20 | train_loss=1.4648 | val_acc=0.4802 | val_iou=0.4151 | val_perf=0.4476
# Epoch 18/20 | train_loss=1.3960 | val_acc=0.5007 | val_iou=0.3943 | val_perf=0.4475
# Epoch 19/20 | train_loss=1.3312 | val_acc=0.5348 | val_iou=0.4298 | val_perf=0.4823
# Epoch 20/20 | train_loss=1.2696 | val_acc=0.5630 | val_iou=0.4104 | val_perf=0.4867
# Finished — best_perf=0.4867
#
# === deep | lr=0.01 | wd=0.0 ===
# Epoch 01/20 | train_loss=2.2816 | val_acc=0.2878 | val_iou=0.4228 | val_perf=0.3553
# Epoch 02/20 | train_loss=1.6129 | val_acc=0.6568 | val_iou=0.4401 | val_perf=0.5484
# Epoch 03/20 | train_loss=0.8814 | val_acc=0.8445 | val_iou=0.3267 | val_perf=0.5856
# Epoch 04/20 | train_loss=0.5233 | val_acc=0.8850 | val_iou=0.3886 | val_perf=0.6368
# Epoch 05/20 | train_loss=0.3766 | val_acc=0.9040 | val_iou=0.4059 | val_perf=0.6549
# Epoch 06/20 | train_loss=0.2973 | val_acc=0.9080 | val_iou=0.3786 | val_perf=0.6433
# Epoch 07/20 | train_loss=0.2502 | val_acc=0.9020 | val_iou=0.4143 | val_perf=0.6581
# Epoch 08/20 | train_loss=0.2242 | val_acc=0.9118 | val_iou=0.4002 | val_perf=0.6560
# Epoch 09/20 | train_loss=0.1843 | val_acc=0.9175 | val_iou=0.4008 | val_perf=0.6591
# Epoch 10/20 | train_loss=0.1583 | val_acc=0.9228 | val_iou=0.3670 | val_perf=0.6449
# Epoch 11/20 | train_loss=0.1369 | val_acc=0.9212 | val_iou=0.4072 | val_perf=0.6642
# Epoch 12/20 | train_loss=0.1249 | val_acc=0.9205 | val_iou=0.3662 | val_perf=0.6433
# Epoch 13/20 | train_loss=0.1114 | val_acc=0.9213 | val_iou=0.4199 | val_perf=0.6706
# Epoch 14/20 | train_loss=0.1031 | val_acc=0.9228 | val_iou=0.3781 | val_perf=0.6505
# Epoch 15/20 | train_loss=0.0894 | val_acc=0.9205 | val_iou=0.3949 | val_perf=0.6577
# Epoch 16/20 | train_loss=0.0942 | val_acc=0.9215 | val_iou=0.3783 | val_perf=0.6499
# Epoch 17/20 | train_loss=0.0779 | val_acc=0.9238 | val_iou=0.3936 | val_perf=0.6587
# Epoch 18/20 | train_loss=0.0764 | val_acc=0.9213 | val_iou=0.3334 | val_perf=0.6274
# Early stopping at epoch 18
# Finished — best_perf=0.6706
#
# === deep | lr=0.01 | wd=0.0001 ===
# Epoch 01/20 | train_loss=2.2913 | val_acc=0.2768 | val_iou=0.4306 | val_perf=0.3537
# Epoch 02/20 | train_loss=1.6133 | val_acc=0.6660 | val_iou=0.3380 | val_perf=0.5020
# Epoch 03/20 | train_loss=0.8339 | val_acc=0.8473 | val_iou=0.4093 | val_perf=0.6283
# Epoch 04/20 | train_loss=0.5029 | val_acc=0.8832 | val_iou=0.3895 | val_perf=0.6363
# Epoch 05/20 | train_loss=0.3746 | val_acc=0.8983 | val_iou=0.3361 | val_perf=0.6172
# Epoch 06/20 | train_loss=0.3027 | val_acc=0.9128 | val_iou=0.4108 | val_perf=0.6618
# Epoch 07/20 | train_loss=0.2483 | val_acc=0.9120 | val_iou=0.3656 | val_perf=0.6388
# Epoch 08/20 | train_loss=0.2161 | val_acc=0.9167 | val_iou=0.3939 | val_perf=0.6553
# Epoch 09/20 | train_loss=0.1835 | val_acc=0.9177 | val_iou=0.4333 | val_perf=0.6755
# Epoch 10/20 | train_loss=0.1622 | val_acc=0.9155 | val_iou=0.4026 | val_perf=0.6591
# Epoch 11/20 | train_loss=0.1388 | val_acc=0.9192 | val_iou=0.3891 | val_perf=0.6542
# Epoch 12/20 | train_loss=0.1290 | val_acc=0.9205 | val_iou=0.4445 | val_perf=0.6825
# Epoch 13/20 | train_loss=0.1122 | val_acc=0.9207 | val_iou=0.3736 | val_perf=0.6471
# Epoch 14/20 | train_loss=0.1017 | val_acc=0.9137 | val_iou=0.3736 | val_perf=0.6437
# Epoch 15/20 | train_loss=0.0944 | val_acc=0.9228 | val_iou=0.4048 | val_perf=0.6638
# Epoch 16/20 | train_loss=0.0830 | val_acc=0.9175 | val_iou=0.3990 | val_perf=0.6583
# Epoch 17/20 | train_loss=0.0804 | val_acc=0.9202 | val_iou=0.3946 | val_perf=0.6574
# Early stopping at epoch 17
# Finished — best_perf=0.6825
#
# === deep | lr=0.001 | wd=0.0 ===
# Epoch 01/20 | train_loss=2.6358 | val_acc=0.1055 | val_iou=0.2290 | val_perf=0.1673
# Epoch 02/20 | train_loss=2.4941 | val_acc=0.1498 | val_iou=0.3764 | val_perf=0.2631
# Epoch 03/20 | train_loss=2.3044 | val_acc=0.1933 | val_iou=0.3764 | val_perf=0.2849
# Epoch 04/20 | train_loss=2.1535 | val_acc=0.2373 | val_iou=0.3883 | val_perf=0.3128
# Epoch 05/20 | train_loss=2.0932 | val_acc=0.2180 | val_iou=0.3953 | val_perf=0.3067
# Epoch 06/20 | train_loss=2.0518 | val_acc=0.2587 | val_iou=0.4131 | val_perf=0.3359
# Epoch 07/20 | train_loss=2.0019 | val_acc=0.2598 | val_iou=0.3833 | val_perf=0.3216
# Epoch 08/20 | train_loss=1.9462 | val_acc=0.2752 | val_iou=0.4363 | val_perf=0.3557
# Epoch 09/20 | train_loss=1.8841 | val_acc=0.3458 | val_iou=0.4365 | val_perf=0.3912
# Epoch 10/20 | train_loss=1.8127 | val_acc=0.3790 | val_iou=0.4077 | val_perf=0.3933
# Epoch 11/20 | train_loss=1.6959 | val_acc=0.4663 | val_iou=0.3828 | val_perf=0.4246
# Epoch 12/20 | train_loss=1.5206 | val_acc=0.5508 | val_iou=0.3984 | val_perf=0.4746
# Epoch 13/20 | train_loss=1.3453 | val_acc=0.6057 | val_iou=0.3840 | val_perf=0.4948
# Epoch 14/20 | train_loss=1.2054 | val_acc=0.6603 | val_iou=0.3980 | val_perf=0.5292
# Epoch 15/20 | train_loss=1.0661 | val_acc=0.6808 | val_iou=0.3938 | val_perf=0.5373
# Epoch 16/20 | train_loss=0.9392 | val_acc=0.7210 | val_iou=0.3812 | val_perf=0.5511
# Epoch 17/20 | train_loss=0.8278 | val_acc=0.7792 | val_iou=0.3819 | val_perf=0.5805
# Epoch 18/20 | train_loss=0.7424 | val_acc=0.8132 | val_iou=0.3959 | val_perf=0.6045
# Epoch 19/20 | train_loss=0.6651 | val_acc=0.8273 | val_iou=0.3865 | val_perf=0.6069
# Epoch 20/20 | train_loss=0.6002 | val_acc=0.8412 | val_iou=0.3794 | val_perf=0.6103
# Finished — best_perf=0.6103
#
# === deep | lr=0.001 | wd=0.0001 ===
# Epoch 01/20 | train_loss=2.6343 | val_acc=0.1137 | val_iou=0.2282 | val_perf=0.1709
# Epoch 02/20 | train_loss=2.4788 | val_acc=0.1710 | val_iou=0.3799 | val_perf=0.2755
# Epoch 03/20 | train_loss=2.2986 | val_acc=0.1853 | val_iou=0.3691 | val_perf=0.2772
# Epoch 04/20 | train_loss=2.1511 | val_acc=0.2157 | val_iou=0.3973 | val_perf=0.3065
# Epoch 05/20 | train_loss=2.0854 | val_acc=0.2412 | val_iou=0.4149 | val_perf=0.3280
# Epoch 06/20 | train_loss=2.0369 | val_acc=0.2422 | val_iou=0.4188 | val_perf=0.3305
# Epoch 07/20 | train_loss=1.9905 | val_acc=0.2768 | val_iou=0.4208 | val_perf=0.3488
# Epoch 08/20 | train_loss=1.9393 | val_acc=0.2587 | val_iou=0.4120 | val_perf=0.3354
# Epoch 09/20 | train_loss=1.8859 | val_acc=0.3423 | val_iou=0.4203 | val_perf=0.3813
# Epoch 10/20 | train_loss=1.8260 | val_acc=0.3845 | val_iou=0.4325 | val_perf=0.4085
# Epoch 11/20 | train_loss=1.7331 | val_acc=0.4457 | val_iou=0.4371 | val_perf=0.4414
# Epoch 12/20 | train_loss=1.5752 | val_acc=0.4945 | val_iou=0.4152 | val_perf=0.4548
# Epoch 13/20 | train_loss=1.4130 | val_acc=0.5790 | val_iou=0.4171 | val_perf=0.4981
# Epoch 14/20 | train_loss=1.2700 | val_acc=0.6215 | val_iou=0.3984 | val_perf=0.5099
# Epoch 15/20 | train_loss=1.1478 | val_acc=0.6620 | val_iou=0.4110 | val_perf=0.5365
# Epoch 16/20 | train_loss=1.0155 | val_acc=0.7335 | val_iou=0.4163 | val_perf=0.5749
# Epoch 17/20 | train_loss=0.9023 | val_acc=0.7473 | val_iou=0.3775 | val_perf=0.5624
# Epoch 18/20 | train_loss=0.8021 | val_acc=0.7690 | val_iou=0.3968 | val_perf=0.5829
# Epoch 19/20 | train_loss=0.7206 | val_acc=0.7983 | val_iou=0.3696 | val_perf=0.5840
# Epoch 20/20 | train_loss=0.6423 | val_acc=0.8312 | val_iou=0.3739 | val_perf=0.6025
# Finished — best_perf=0.6025
#
# === wide | lr=0.01 | wd=0.0 ===
# Epoch 01/20 | train_loss=2.3310 | val_acc=0.2020 | val_iou=0.4687 | val_perf=0.3354
# Epoch 02/20 | train_loss=1.7778 | val_acc=0.5258 | val_iou=0.3817 | val_perf=0.4538
# Epoch 03/20 | train_loss=1.0866 | val_acc=0.7212 | val_iou=0.3697 | val_perf=0.5454
# Epoch 04/20 | train_loss=0.6912 | val_acc=0.8102 | val_iou=0.4200 | val_perf=0.6151
# Epoch 05/20 | train_loss=0.5005 | val_acc=0.8667 | val_iou=0.3916 | val_perf=0.6291
# Epoch 06/20 | train_loss=0.3810 | val_acc=0.8748 | val_iou=0.4347 | val_perf=0.6548
# Epoch 07/20 | train_loss=0.2994 | val_acc=0.8652 | val_iou=0.3940 | val_perf=0.6296
# Epoch 08/20 | train_loss=0.2374 | val_acc=0.8863 | val_iou=0.4351 | val_perf=0.6607
# Epoch 09/20 | train_loss=0.1884 | val_acc=0.8803 | val_iou=0.4471 | val_perf=0.6637
# Epoch 10/20 | train_loss=0.1586 | val_acc=0.8810 | val_iou=0.4318 | val_perf=0.6564
# Epoch 11/20 | train_loss=0.1311 | val_acc=0.8795 | val_iou=0.4316 | val_perf=0.6556
# Epoch 12/20 | train_loss=0.1182 | val_acc=0.8730 | val_iou=0.4584 | val_perf=0.6657
# Epoch 13/20 | train_loss=0.0972 | val_acc=0.8865 | val_iou=0.4045 | val_perf=0.6455
# Epoch 14/20 | train_loss=0.0845 | val_acc=0.8870 | val_iou=0.4196 | val_perf=0.6533
# Epoch 15/20 | train_loss=0.0775 | val_acc=0.8938 | val_iou=0.4510 | val_perf=0.6724
# Epoch 16/20 | train_loss=0.0629 | val_acc=0.8900 | val_iou=0.4363 | val_perf=0.6632
# Epoch 17/20 | train_loss=0.0604 | val_acc=0.8867 | val_iou=0.4471 | val_perf=0.6669
# Epoch 18/20 | train_loss=0.0548 | val_acc=0.8885 | val_iou=0.4484 | val_perf=0.6684
# Epoch 19/20 | train_loss=0.0464 | val_acc=0.8797 | val_iou=0.4393 | val_perf=0.6595
# Epoch 20/20 | train_loss=0.0439 | val_acc=0.8900 | val_iou=0.4514 | val_perf=0.6707
# Early stopping at epoch 20
# Finished — best_perf=0.6724
#
# === wide | lr=0.01 | wd=0.0001 ===
# Epoch 01/20 | train_loss=2.3134 | val_acc=0.2475 | val_iou=0.4516 | val_perf=0.3495
# Epoch 02/20 | train_loss=1.8082 | val_acc=0.5137 | val_iou=0.4198 | val_perf=0.4667
# Epoch 03/20 | train_loss=1.1706 | val_acc=0.7212 | val_iou=0.3538 | val_perf=0.5375
# Epoch 04/20 | train_loss=0.7347 | val_acc=0.8085 | val_iou=0.3295 | val_perf=0.5690
# Epoch 05/20 | train_loss=0.5250 | val_acc=0.8523 | val_iou=0.4325 | val_perf=0.6424
# Epoch 06/20 | train_loss=0.3939 | val_acc=0.8717 | val_iou=0.4514 | val_perf=0.6615
# Epoch 07/20 | train_loss=0.2954 | val_acc=0.8640 | val_iou=0.4372 | val_perf=0.6506
# Epoch 08/20 | train_loss=0.2404 | val_acc=0.8788 | val_iou=0.4402 | val_perf=0.6595
# Epoch 09/20 | train_loss=0.1974 | val_acc=0.8767 | val_iou=0.4360 | val_perf=0.6563
# Epoch 10/20 | train_loss=0.1550 | val_acc=0.8853 | val_iou=0.4745 | val_perf=0.6799
# Epoch 11/20 | train_loss=0.1296 | val_acc=0.8863 | val_iou=0.4881 | val_perf=0.6872
# Epoch 12/20 | train_loss=0.1045 | val_acc=0.8872 | val_iou=0.3550 | val_perf=0.6211
# Epoch 13/20 | train_loss=0.0940 | val_acc=0.8677 | val_iou=0.4315 | val_perf=0.6496
# Epoch 14/20 | train_loss=0.0844 | val_acc=0.8875 | val_iou=0.4834 | val_perf=0.6855
# Epoch 15/20 | train_loss=0.0721 | val_acc=0.8808 | val_iou=0.4495 | val_perf=0.6652
# Epoch 16/20 | train_loss=0.0663 | val_acc=0.8882 | val_iou=0.4723 | val_perf=0.6802
# Early stopping at epoch 16
# Finished — best_perf=0.6872
#
# === wide | lr=0.001 | wd=0.0 ===
# Epoch 01/20 | train_loss=2.6289 | val_acc=0.1242 | val_iou=0.2243 | val_perf=0.1742
# Epoch 02/20 | train_loss=2.5325 | val_acc=0.1480 | val_iou=0.3661 | val_perf=0.2570
# Epoch 03/20 | train_loss=2.3441 | val_acc=0.2027 | val_iou=0.4600 | val_perf=0.3313
# Epoch 04/20 | train_loss=2.1416 | val_acc=0.2243 | val_iou=0.4410 | val_perf=0.3327
# Epoch 05/20 | train_loss=2.0674 | val_acc=0.2290 | val_iou=0.4594 | val_perf=0.3442
# Epoch 06/20 | train_loss=2.0313 | val_acc=0.2435 | val_iou=0.4509 | val_perf=0.3472
# Epoch 07/20 | train_loss=1.9789 | val_acc=0.2638 | val_iou=0.4076 | val_perf=0.3357
# Epoch 08/20 | train_loss=1.9312 | val_acc=0.2460 | val_iou=0.4499 | val_perf=0.3479
# Epoch 09/20 | train_loss=1.8699 | val_acc=0.3235 | val_iou=0.4688 | val_perf=0.3961
# Epoch 10/20 | train_loss=1.7804 | val_acc=0.3688 | val_iou=0.4302 | val_perf=0.3995
# Epoch 11/20 | train_loss=1.6648 | val_acc=0.4425 | val_iou=0.4455 | val_perf=0.4440
# Epoch 12/20 | train_loss=1.5162 | val_acc=0.4983 | val_iou=0.4306 | val_perf=0.4645
# Epoch 13/20 | train_loss=1.3422 | val_acc=0.5340 | val_iou=0.3988 | val_perf=0.4664
# Epoch 14/20 | train_loss=1.1837 | val_acc=0.6312 | val_iou=0.4022 | val_perf=0.5167
# Epoch 15/20 | train_loss=1.0610 | val_acc=0.6633 | val_iou=0.4127 | val_perf=0.5380
# Epoch 16/20 | train_loss=0.9544 | val_acc=0.6932 | val_iou=0.4281 | val_perf=0.5606
# Epoch 17/20 | train_loss=0.8552 | val_acc=0.7378 | val_iou=0.4219 | val_perf=0.5799
# Epoch 18/20 | train_loss=0.7511 | val_acc=0.7715 | val_iou=0.4131 | val_perf=0.5923
# Epoch 19/20 | train_loss=0.6533 | val_acc=0.7817 | val_iou=0.4263 | val_perf=0.6040
# Epoch 20/20 | train_loss=0.5677 | val_acc=0.8045 | val_iou=0.4167 | val_perf=0.6106
# Finished — best_perf=0.6106
#
# === wide | lr=0.001 | wd=0.0001 ===
# Epoch 01/20 | train_loss=2.6199 | val_acc=0.1153 | val_iou=0.2477 | val_perf=0.1815
# Epoch 02/20 | train_loss=2.5136 | val_acc=0.1458 | val_iou=0.4016 | val_perf=0.2737
# Epoch 03/20 | train_loss=2.2978 | val_acc=0.1990 | val_iou=0.3914 | val_perf=0.2952
# Epoch 04/20 | train_loss=2.1190 | val_acc=0.2285 | val_iou=0.4294 | val_perf=0.3289
# Epoch 05/20 | train_loss=2.0575 | val_acc=0.2188 | val_iou=0.4145 | val_perf=0.3167
# Epoch 06/20 | train_loss=2.0104 | val_acc=0.2657 | val_iou=0.4394 | val_perf=0.3525
# Epoch 07/20 | train_loss=1.9685 | val_acc=0.2767 | val_iou=0.4303 | val_perf=0.3535
# Epoch 08/20 | train_loss=1.9096 | val_acc=0.2755 | val_iou=0.4318 | val_perf=0.3536
# Epoch 09/20 | train_loss=1.8460 | val_acc=0.3320 | val_iou=0.4613 | val_perf=0.3966
# Epoch 10/20 | train_loss=1.7543 | val_acc=0.3655 | val_iou=0.4386 | val_perf=0.4020
# Epoch 11/20 | train_loss=1.6310 | val_acc=0.4180 | val_iou=0.3937 | val_perf=0.4059
# Epoch 12/20 | train_loss=1.4655 | val_acc=0.5287 | val_iou=0.4199 | val_perf=0.4743
# Epoch 13/20 | train_loss=1.2831 | val_acc=0.5275 | val_iou=0.4268 | val_perf=0.4771
# Epoch 14/20 | train_loss=1.1422 | val_acc=0.6510 | val_iou=0.4190 | val_perf=0.5350
# Epoch 15/20 | train_loss=1.0189 | val_acc=0.6960 | val_iou=0.3988 | val_perf=0.5474
# Epoch 16/20 | train_loss=0.9116 | val_acc=0.7125 | val_iou=0.4077 | val_perf=0.5601
# Epoch 17/20 | train_loss=0.8070 | val_acc=0.7498 | val_iou=0.4166 | val_perf=0.5832
# Epoch 18/20 | train_loss=0.7012 | val_acc=0.7733 | val_iou=0.4049 | val_perf=0.5891
# Epoch 19/20 | train_loss=0.6179 | val_acc=0.8003 | val_iou=0.4290 | val_perf=0.6146
# Epoch 20/20 | train_loss=0.5388 | val_acc=0.8095 | val_iou=0.4351 | val_perf=0.6223
# Finished — best_perf=0.6223
#
# Best run: model=wide | lr=0.01 | wd=0.0001 | perf=0.6872

# %% [markdown]
# ## Traning and validation curves

# %%
fig, axes = plt.subplots(len(model_configs), len(param_grid),
                         figsize=(5 * len(param_grid), 4 * len(model_configs)),
                         squeeze=False, sharey='row')

for i, model_name in enumerate(model_configs):
    for j, hparams in enumerate(param_grid):
        run_key = (model_name, hparams["lr"], hparams["weight_decay"])
        _, history, _ = all_results[run_key]
        ax = axes[i][j]
        ax.plot([h["train_loss"] for h in history], label="Train Loss")
        ax.plot([h["val_perf"] for h in history], label="Val Perf")
        ax.set_title(f"{model_name}\nlr={hparams['lr']}, wd={hparams['weight_decay']}", fontsize=10)
        ax.set_xlabel("Epoch")
        ax.set_ylabel("Loss / Perf")
        ax.legend()

fig.suptitle("Training & Validation Curves", fontsize=14, y=1.02)
plt.tight_layout()
plt.savefig("figures/loss_curves_localization.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Model evaluation

# %%
def pred_vs_actual(dataset, pred, i, pc_has_sigmoid=False, display_ds=None):
    img_source = display_ds if display_ds is not None else dataset
    img = img_source.tensors[0][i]         
    y   = dataset.tensors[1][i].float()  
    H, W = img.shape[-2], img.shape[-1]

    pc_true = int(y[0].item())
    true_label = int(y[5].item()) if pc_true == 1 else None

    gt_cxcywh = y[1:5].unsqueeze(0)
  
    pr_cxcywh = pred[i][1:5].clone()
    pr_cxcywh[2:] = pr_cxcywh[2:].abs().clamp(min=1e-6)
    pr_cxcywh = pr_cxcywh.unsqueeze(0)

    gt_xyxy = box_convert(gt_cxcywh, "cxcywh", "xyxy")
    pr_xyxy = box_convert(pr_cxcywh, "cxcywh", "xyxy")

    scale = torch.tensor([W, H, W, H], dtype=torch.float32).unsqueeze(0)
    gt_xyxy = gt_xyxy * scale
    pr_xyxy = pr_xyxy * scale

    img_u8 = (img.clamp(0,1) * 255).to(torch.uint8).repeat(3,1,1)
    pred_label = int(torch.argmax(pred[i][5:]).item())

    if pc_true == 0:
        return img_u8.permute(1,2,0).numpy(), pc_true, pred_label, true_label

    boxes = torch.cat([gt_xyxy, pr_xyxy], dim=0)
    colors = ["green", "red"]
    drawn = torchvision.utils.draw_bounding_boxes(img_u8, boxes, colors=colors, width=1)

    return drawn.permute(1,2,0).numpy(), pc_true, pred_label, true_label

# %% [markdown]
# # show predictions

# %%
def show_predictions(model, ds, preprocessor, n=7, device="cpu", display_ds=None, save_path=None):
    model.eval()

    images = ds.tensors[0][:n].to(device)

    with torch.no_grad():
        try:
            x = preprocessor(images)
        except TypeError:
            x = preprocessor(images, None)

        preds = model(x).cpu()

    cols = 4
    rows = math.ceil(n / cols)

    fig, axes = plt.subplots(rows, cols, figsize=(4*cols, 4*rows))
    axes = axes.flatten()

    for i in range(n):
        img, pc, pred_label, true_label = pred_vs_actual(ds, preds, i, display_ds=display_ds)

        axes[i].imshow(img)
        axes[i].set_title(f"Object: {pc}, Number: {true_label}, Pred: {pred_label}")
        axes[i].axis("off")

    for j in range(n, len(axes)):
        axes[j].axis("off")

    plt.tight_layout()
    plt.savefig(save_path, bbox_inches="tight")
    plt.show()

show_predictions(best_model, norm_train, lambda x: x.to(device), n=16, device=device, display_ds=train, save_path="figures/train_prediction_localization.png")

# %%
show_predictions(best_model, norm_val, lambda x: x.to(device), n=16, device=device, display_ds=val, save_path="figures/validation_prediction_localization.png")

# %%
show_predictions(best_model, norm_test, lambda x: x.to(device), n=16, device=device, display_ds=test, save_path="figures/test_prediction_localization.png")

# %%
test_loader = torch.utils.data.DataLoader(norm_test, batch_size=64, shuffle=False, num_workers=0)
_, test_acc, test_iou, test_perf = predict(best_model, test_loader)
print(f"Test Accuracy:    {test_acc:.4f}")
print(f"Test IoU:         {test_iou:.4f}")
print(f"Test Performance: {test_perf:.4f}")
# Out:
# Test Accuracy:    0.8820
# Test IoU:         0.4876
# Test Performance: 0.6848
